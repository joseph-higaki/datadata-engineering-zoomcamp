# %% [markdown]
# This is using local spark from a  vm instance in gcp cloud
# Let's say our host in [`~./ssh/config`](./config) is called `de-zoomcamp-spark-instance`
#
# # Access ssh
# (either from the dev container terminal or the host win machine, doesn't matter)
# `ssh de-zoomcamp-spark-instance`
#
# ### Ensure env vars
# After ensuring spark / python [env variables are well set](./install_local_pyspark.md#ensuring-env-variables)
#
# ### Run Jupyter Notebook
# Run Jupyter Notebook
# `jupyter notebook` Notice it will launch in `:8888`
#
#
# # Forward Port dev container - cloud VM
# This needs to be done from vs code terminal, as it will be:
# Forward the port from the cloud VM into a **local port of the dev container**
# `ssh -L 8890:localhost:8888 spark_jhigaki_gcp@de-zoomcamp-spark-instance`
#
# Choose Jupyter Server, using URL from command ran abotve starting jupyter notebook
#
# Notice specifying localhost:8890

# %%
import pyspark
pyspark.__file__
# Out:
# '/home/spark_jhigaki_gcp/spark/spark-3.4.4-bin-hadoop3/python/pyspark/__init__.py'

# %%
from sys import path
path
# Out:
# ['/usr/local/python/3.9.20/lib/python39.zip',
#  '/usr/local/python/3.9.20/lib/python3.9',
#  '/usr/local/python/3.9.20/lib/python3.9/lib-dynload',
#  '',
#  '/home/vscode/.local/lib/python3.9/site-packages',
#  '/usr/local/python/3.9.20/lib/python3.9/site-packages']

# %%
import sys 
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' from '/usr/local/python/3.9.20/lib/python3.9/codecs.py'>,
#  'encodings.aliases': <module 'encodings.aliases' from '/usr/local/python/3.9.20/lib/python3.9/encodings/aliases.py'>,
#  'encodings': <module 'encodings' from '/usr/local/python/3.9.20/lib/python3.9/encodings/__init__.py'>,
# ...
